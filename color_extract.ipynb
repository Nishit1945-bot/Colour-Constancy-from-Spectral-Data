# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishit1945-bot/Colour-Constancy-from-Spectral-Data/blob/main/color_extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np

img_path ='/content/drive/MyDrive/image.jpg'
img =cv2.imread(img_path)
print(img.shape)
# Out:
# (612, 612, 3)

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
img_path ='/content/drive/MyDrive/image.jpg'
img =cv2.imread(img_path)
img = cv2.resize(img, (612,612))
#cv2_imshow(img)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# cv2_imshow(gray_img)
print(gray_img.shape)
gray_img
gray_img_copy = np.copy(gray_img)
gray_img_copy[gray_img_copy[:,:]< 180]=0
#cv2_imshow(gray_img_copy)
img[(img[:,:,0]>100)|(img[:,:,1]<225)|(img[:,:,2]<150)]=0
cv2_imshow(img)
# Out:
# (612, 612)
# <PIL.Image.Image image mode=RGB size=612x612 at 0x7F4284A397C0>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img_path ='/content/drive/MyDrive/random-pixels-big.png'
img = cv2.imread(img_path)
img =cv2.resize(img,(1200,1800))
cv2_imshow(img)
gray_img = cv2.cvtColor (img, cv2.COLOR_BGR2GRAY )
#cv2_imshow(gray_img)
gray_img[gray_img[:,:]< 200]=0
#cv2_imshow(gray_img)
img[(img[:,:,0]<120)|(img[:,:,1]>125)|(img[:,:,2]>90)]=0
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1800 at 0x7F4284A32D90>
# <PIL.Image.Image image mode=RGB size=1200x1800 at 0x7F4284A32CD0>

# %% [markdown]
# # New Section
